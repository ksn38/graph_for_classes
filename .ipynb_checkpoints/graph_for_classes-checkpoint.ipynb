# %%
import re
from collections import Counter
import os
import matplotlib.pyplot as plt
import networkx as nx

# %%
path_of_lib = '/home/ksn38/.local/lib/python3.6/site-packages/geopandas/'

# %%
#open .py file and get names classes with regex
def open_and_re(path):
    with open(path, 'r', encoding='utf-8') as file:
        classes = re.findall('class\s\w+\(\w+\)|class\s\w+\:', file.read())
        list_classes = []
        list_classes_for_graph = []
        for i in classes:
            list_1_or_2_classes = re.findall('\w+', i[6:])
            list_classes.extend(list_1_or_2_classes)
            if len(list_1_or_2_classes) > 1:
                list_classes_for_graph.append(list_1_or_2_classes)
        counter_classes = Counter(list_classes)
        if len(classes) > 0:
            print(f'====={path}=====')
        for c in classes:
            c_key = re.findall('\w+', c[6:])[0]
            print(f'{c} = {counter_classes[c_key]}') 
    return list_classes, list_classes_for_graph

#run previous function on multiple files
def printer(tuple_from_oswalk):
    files = tuple_from_oswalk[2]
    list_classes_printer = []
    list_classes_for_graph_printer = []
    for f in files:
        if tuple_from_oswalk[0][-1] != '/' and f[-3:] == '.py':
            list_classes_printer.extend(open_and_re(tuple_from_oswalk[0] + '/' + f)[0])
            list_classes_for_graph_printer.extend(open_and_re(tuple_from_oswalk[0] + '/' + f)[1])
        elif tuple_from_oswalk[0][-1] == '/' and f[-3:] == '.py':
            list_classes_printer.extend(open_and_re(tuple_from_oswalk[0] + f)[0])
            list_classes_for_graph_printer.extend(open_and_re(tuple_from_oswalk[0] + f)[1])
    return list_classes_printer, list_classes_for_graph_printer

# %%
#run previous function on multiple directories
list_of_all_classes = []
list_of_all_classes_for_graph = []

for i in os.walk(path_of_lib):
    list_of_all_classes.extend(printer(i)[0])
    list_of_all_classes_for_graph.extend(printer(i)[1])

print('ALL CLASSES', Counter(list_of_all_classes))
# Out:
# =====/home/ksn38/.local/lib/python3.6/site-packages/geopandas/_config.py=====
# class Options(object) = 1
# =====/home/ksn38/.local/lib/python3.6/site-packages/geopandas/_config.py=====
# class Options(object) = 1
# =====/home/ksn38/.local/lib/python3.6/site-packages/geopandas/sindex.py=====
# class BaseSpatialIndex: = 1
# =====/home/ksn38/.local/lib/python3.6/site-packages/geopandas/sindex.py=====
# class BaseSpatialIndex: = 1
# =====/home/ksn38/.local/lib/python3.6/site-packages/geopandas/plotting.py=====
# class GeoplotAccessor(PlotAccessor) = 1
# =====/home/ksn38/.local/lib/python3.6/site-packages/geopandas/plotting.py=====
# class GeoplotAccessor(PlotAccessor) = 1
# =====/home/ksn38/.local/lib/python3.6/site-packages/geopandas/base.py=====
# class GeoPandasBase(object) = 1
# class _CoordinateIndexer(object) = 1
# =====/home/ksn38/.local/lib/python3.6/site-packages/geopandas/base.py=====
# class GeoPandasBase(object) = 1
# class _CoordinateIndexer(object) = 1
# =====/home/ksn38/.local/lib/python3.6/site-packages/geopandas/array.py=====
# class GeometryDtype(ExtensionDtype) = 1
# class GeometryArray(ExtensionArray) = 1
# =====/home/ksn38/.local/lib/python3.6/site-packages/geopandas/array.py=====
# class GeometryDtype(ExtensionDtype) = 1
# class GeometryArray(ExtensionArray) = 1
# =====/home/ksn38/.local/lib/python3.6/site-packages/geopandas/_config.py=====
# class Options(object) = 1
# =====/home/ksn38/.local/lib/python3.6/site-packages/geopandas/_config.py=====
# class Options(object) = 1
# =====/home/ksn38/.local/lib/python3.6/site-packages/geopandas/sindex.py=====
# class BaseSpatialIndex: = 1
# =====/home/ksn38/.local/lib/python3.6/site-packages/geopandas/sindex.py=====
# class BaseSpatialIndex: = 1
# =====/home/ksn38/.local/lib/python3.6/site-packages/geopandas/plotting.py=====
# class GeoplotAccessor(PlotAccessor) = 1
# =====/home/ksn38/.local/lib/python3.6/site-packages/geopandas/plotting.py=====
# class GeoplotAccessor(PlotAccessor) = 1
# =====/home/ksn38/.local/lib/python3.6/site-packages/geopandas/base.py=====
# class GeoPandasBase(object) = 1
# class _CoordinateIndexer(object) = 1
# =====/home/ksn38/.local/lib/python3.6/site-packages/geopandas/base.py=====
# class GeoPandasBase(object) = 1
# class _CoordinateIndexer(object) = 1
# =====/home/ksn38/.local/lib/python3.6/site-packages/geopandas/array.py=====
# class GeometryDtype(ExtensionDtype) = 1
# class GeometryArray(ExtensionArray) = 1
# =====/home/ksn38/.local/lib/python3.6/site-packages/geopandas/array.py=====
# class GeometryDtype(ExtensionDtype) = 1
# class GeometryArray(ExtensionArray) = 1
# =====/home/ksn38/.local/lib/python3.6/site-packages/geopandas/tools/tests/test_sjoin.py=====
# class TestSpatialJoin: = 1
# class TestSpatialJoinNYBB: = 1
# class TestSpatialJoinNaturalEarth: = 1
# =====/home/ksn38/.local/lib/python3.6/site-packages/geopandas/tools/tests/test_sjoin.py=====
# class TestSpatialJoin: = 1
# class TestSpatialJoinNYBB: = 1
# class TestSpatialJoinNaturalEarth: = 1
# =====/home/ksn38/.local/lib/python3.6/site-packages/geopandas/tools/tests/test_tools.py=====
# class TestTools: = 1
# =====/home/ksn38/.local/lib/python3.6/site-packages/geopandas/tools/tests/test_tools.py=====
# class TestTools: = 1
# =====/home/ksn38/.local/lib/python3.6/site-packages/geopandas/tools/tests/test_sjoin.py=====
# class TestSpatialJoin: = 1
# class TestSpatialJoinNYBB: = 1
# class TestSpatialJoinNaturalEarth: = 1
# =====/home/ksn38/.local/lib/python3.6/site-packages/geopandas/tools/tests/test_sjoin.py=====
# class TestSpatialJoin: = 1
# class TestSpatialJoinNYBB: = 1
# class TestSpatialJoinNaturalEarth: = 1
# =====/home/ksn38/.local/lib/python3.6/site-packages/geopandas/tools/tests/test_tools.py=====
# class TestTools: = 1
# =====/home/ksn38/.local/lib/python3.6/site-packages/geopandas/tools/tests/test_tools.py=====
# class TestTools: = 1
# =====/home/ksn38/.local/lib/python3.6/site-packages/geopandas/tests/test_crs.py=====
# class TestGeometryArrayCRS: = 1
# class TestSetCRS: = 1
# =====/home/ksn38/.local/lib/python3.6/site-packages/geopandas/tests/test_crs.py=====
# class TestGeometryArrayCRS: = 1
# class TestSetCRS: = 1
# =====/home/ksn38/.local/lib/python3.6/site-packages/geopandas/tests/test_array.py=====
# class Point: = 1
# class TestEstimateUtmCrs: = 1
# =====/home/ksn38/.local/lib/python3.6/site-packages/geopandas/tests/test_array.py=====
# class Point: = 1
# class TestEstimateUtmCrs: = 1
# =====/home/ksn38/.local/lib/python3.6/site-packages/geopandas/tests/test_sindex.py=====
# class TestSeriesSindex: = 1
# class TestFrameSindex: = 1
# class TestJoinSindex: = 1
# class TestPygeosInterface: = 1
# =====/home/ksn38/.local/lib/python3.6/site-packages/geopandas/tests/test_sindex.py=====
# class TestSeriesSindex: = 1
# class TestFrameSindex: = 1
# class TestJoinSindex: = 1
# class TestPygeosInterface: = 1
# =====/home/ksn38/.local/lib/python3.6/site-packages/geopandas/tests/test_geom_methods.py=====
# class TestGeomMethods: = 1
# =====/home/ksn38/.local/lib/python3.6/site-packages/geopandas/tests/test_geom_methods.py=====
# class TestGeomMethods: = 1
# =====/home/ksn38/.local/lib/python3.6/site-packages/geopandas/tests/test_geodataframe.py=====
# class TestDataFrame: = 1
# class Placemark(object) = 1
# class TestConstructor: = 1
# =====/home/ksn38/.local/lib/python3.6/site-packages/geopandas/tests/test_geodataframe.py=====
# class TestDataFrame: = 1
# class Placemark(object) = 1
# class TestConstructor: = 1
# =====/home/ksn38/.local/lib/python3.6/site-packages/geopandas/tests/test_geoseries.py=====
# class TestSeries: = 1
# class TestConstructor: = 1
# =====/home/ksn38/.local/lib/python3.6/site-packages/geopandas/tests/test_geoseries.py=====
# class TestSeries: = 1
# class TestConstructor: = 1
# =====/home/ksn38/.local/lib/python3.6/site-packages/geopandas/tests/test_merge.py=====
# class TestMerging: = 1
# =====/home/ksn38/.local/lib/python3.6/site-packages/geopandas/tests/test_merge.py=====
# class TestMerging: = 1
# =====/home/ksn38/.local/lib/python3.6/site-packages/geopandas/tests/test_types.py=====
# class TestSeries: = 1
# class TestDataFrame: = 1
# =====/home/ksn38/.local/lib/python3.6/site-packages/geopandas/tests/test_types.py=====
# class TestSeries: = 1
# class TestDataFrame: = 1
# =====/home/ksn38/.local/lib/python3.6/site-packages/geopandas/tests/test_plotting.py=====
# class TestPointPlotting: = 1
# class TestPointZPlotting: = 1
# class TestLineStringPlotting: = 1
# class TestPolygonPlotting: = 1
# class TestPolygonZPlotting: = 1
# class TestGeometryCollectionPlotting: = 1
# class TestNonuniformGeometryPlotting: = 1
# class TestGeographicAspect: = 1
# class TestMapclassifyPlotting: = 1
# class TestPlotCollections: = 1
# class TestGeoplotAccessor: = 1
# =====/home/ksn38/.local/lib/python3.6/site-packages/geopandas/tests/test_plotting.py=====
# class TestPointPlotting: = 1
# class TestPointZPlotting: = 1
# class TestLineStringPlotting: = 1
# class TestPolygonPlotting: = 1
# class TestPolygonZPlotting: = 1
# class TestGeometryCollectionPlotting: = 1
# class TestNonuniformGeometryPlotting: = 1
# class TestGeographicAspect: = 1
# class TestMapclassifyPlotting: = 1
# class TestPlotCollections: = 1
# class TestGeoplotAccessor: = 1
# =====/home/ksn38/.local/lib/python3.6/site-packages/geopandas/tests/test_crs.py=====
# class TestGeometryArrayCRS: = 1
# class TestSetCRS: = 1
# =====/home/ksn38/.local/lib/python3.6/site-packages/geopandas/tests/test_crs.py=====
# class TestGeometryArrayCRS: = 1
# class TestSetCRS: = 1
# =====/home/ksn38/.local/lib/python3.6/site-packages/geopandas/tests/test_array.py=====
# class Point: = 1
# class TestEstimateUtmCrs: = 1
# =====/home/ksn38/.local/lib/python3.6/site-packages/geopandas/tests/test_array.py=====
# class Point: = 1
# class TestEstimateUtmCrs: = 1
# =====/home/ksn38/.local/lib/python3.6/site-packages/geopandas/tests/test_sindex.py=====
# class TestSeriesSindex: = 1
# class TestFrameSindex: = 1
# class TestJoinSindex: = 1
# class TestPygeosInterface: = 1
# =====/home/ksn38/.local/lib/python3.6/site-packages/geopandas/tests/test_sindex.py=====
# class TestSeriesSindex: = 1
# class TestFrameSindex: = 1
# class TestJoinSindex: = 1
# class TestPygeosInterface: = 1
# =====/home/ksn38/.local/lib/python3.6/site-packages/geopandas/tests/test_geom_methods.py=====
# class TestGeomMethods: = 1
# =====/home/ksn38/.local/lib/python3.6/site-packages/geopandas/tests/test_geom_methods.py=====
# class TestGeomMethods: = 1
# =====/home/ksn38/.local/lib/python3.6/site-packages/geopandas/tests/test_geodataframe.py=====
# class TestDataFrame: = 1
# class Placemark(object) = 1
# class TestConstructor: = 1
# =====/home/ksn38/.local/lib/python3.6/site-packages/geopandas/tests/test_geodataframe.py=====
# class TestDataFrame: = 1
# class Placemark(object) = 1
# class TestConstructor: = 1
# =====/home/ksn38/.local/lib/python3.6/site-packages/geopandas/tests/test_geoseries.py=====
# class TestSeries: = 1
# class TestConstructor: = 1
# =====/home/ksn38/.local/lib/python3.6/site-packages/geopandas/tests/test_geoseries.py=====
# class TestSeries: = 1
# class TestConstructor: = 1
# =====/home/ksn38/.local/lib/python3.6/site-packages/geopandas/tests/test_merge.py=====
# class TestMerging: = 1
# =====/home/ksn38/.local/lib/python3.6/site-packages/geopandas/tests/test_merge.py=====
# class TestMerging: = 1
# =====/home/ksn38/.local/lib/python3.6/site-packages/geopandas/tests/test_types.py=====
# class TestSeries: = 1
# class TestDataFrame: = 1
# =====/home/ksn38/.local/lib/python3.6/site-packages/geopandas/tests/test_types.py=====
# class TestSeries: = 1
# class TestDataFrame: = 1
# =====/home/ksn38/.local/lib/python3.6/site-packages/geopandas/tests/test_plotting.py=====
# class TestPointPlotting: = 1
# class TestPointZPlotting: = 1
# class TestLineStringPlotting: = 1
# class TestPolygonPlotting: = 1
# class TestPolygonZPlotting: = 1
# class TestGeometryCollectionPlotting: = 1
# class TestNonuniformGeometryPlotting: = 1
# class TestGeographicAspect: = 1
# class TestMapclassifyPlotting: = 1
# class TestPlotCollections: = 1
# class TestGeoplotAccessor: = 1
# =====/home/ksn38/.local/lib/python3.6/site-packages/geopandas/tests/test_plotting.py=====
# class TestPointPlotting: = 1
# class TestPointZPlotting: = 1
# class TestLineStringPlotting: = 1
# class TestPolygonPlotting: = 1
# class TestPolygonZPlotting: = 1
# class TestGeometryCollectionPlotting: = 1
# class TestNonuniformGeometryPlotting: = 1
# class TestGeographicAspect: = 1
# class TestMapclassifyPlotting: = 1
# class TestPlotCollections: = 1
# class TestGeoplotAccessor: = 1
# ALL CLASSES Counter({'object': 4, 'TestDataFrame': 2, 'TestConstructor': 2, 'TestSeries': 2, 'Options': 1, 'BaseSpatialIndex': 1, 'GeoplotAccessor': 1, 'PlotAccessor': 1, 'GeoPandasBase': 1, '_CoordinateIndexer': 1, 'GeometryDtype': 1, 'ExtensionDtype': 1, 'GeometryArray': 1, 'ExtensionArray': 1, 'TestSpatialJoin': 1, 'TestSpatialJoinNYBB': 1, 'TestSpatialJoinNaturalEarth': 1, 'TestTools': 1, 'TestGeometryArrayCRS': 1, 'TestSetCRS': 1, 'Point': 1, 'TestEstimateUtmCrs': 1, 'TestSeriesSindex': 1, 'TestFrameSindex': 1, 'TestJoinSindex': 1, 'TestPygeosInterface': 1, 'TestGeomMethods': 1, 'Placemark': 1, 'TestMerging': 1, 'TestPointPlotting': 1, 'TestPointZPlotting': 1, 'TestLineStringPlotting': 1, 'TestPolygonPlotting': 1, 'TestPolygonZPlotting': 1, 'TestGeometryCollectionPlotting': 1, 'TestNonuniformGeometryPlotting': 1, 'TestGeographicAspect': 1, 'TestMapclassifyPlotting': 1, 'TestPlotCollections': 1, 'TestGeoplotAccessor': 1})

# %%
#create graph
plt.figure(figsize=(10,10))
G = nx.Graph()

for i in list_of_all_classes_for_graph:
    G.add_edge(*i, minlen = 1000)

pos = nx.spring_layout(G, k=0.05, iterations=25)
nx.draw_networkx(G, pos, node_color='r', edge_color='b', node_size=100)

plt.show()
