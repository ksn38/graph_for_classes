# %%
import re
from collections import Counter
import os
import matplotlib.pyplot as plt
import networkx as nx

# %%
path_of_lib = '/home/ksn38/.local/lib/python3.6/site-packages/numpy/'

# %%
list_classes = []
list_classes_for_graph = []
list_classes_for_html = []

#open .py file and get names classes with regex
def open_and_re(path, list_classes, list_classes_for_graph):
    with open(path, 'r', encoding='utf-8') as file:
        classes = re.findall('class\s\w+\(\w+\)|class\s\w+\:', file.read())
        for i in classes:
            list_1_or_2_classes = re.findall('\w+', i[6:])
            list_classes.extend(list_1_or_2_classes)
            if len(list_1_or_2_classes) > 1:
                list_classes_for_graph.append(list_1_or_2_classes)
        counter_classes = Counter(list_classes)
        if len(classes) > 0:
            #print(f'====={path}=====')
            list_classes_for_html.append(f'<a href="{path}">=={path}==</a>')
        for c in classes:
            c_key = re.findall('\w+', c[6:])[0]
            #print(f'{c} = {counter_classes[c_key]}') 
            list_classes_for_html.append(f'<div>{c[6:]} = {counter_classes[c_key]}</div>')

#run previous function on multiple files
def printer(tuple_from_oswalk):
    files = tuple_from_oswalk[2]
    for f in files:
        if tuple_from_oswalk[0][-1] != '/' and f[-3:] == '.py':
            open_and_re(tuple_from_oswalk[0] + '/' + f, list_classes, list_classes_for_graph)
        elif tuple_from_oswalk[0][-1] == '/' and f[-3:] == '.py':
            open_and_re(tuple_from_oswalk[0] + f, list_classes, list_classes_for_graph)

# %%
#run previous function on multiple directories
for i in os.walk(path_of_lib):
    printer(i)

counter_classes = Counter(list_classes)

# %%
#create graph
plt.figure(figsize=(30, 30))
G = nx.Graph()

for i in list_classes_for_graph:
    G.add_edge(*i, minlen = 1000)

pos = nx.spring_layout(G, k=0.05, iterations=25)
nx.draw_networkx(G, pos, node_color='r', edge_color='b', node_size=100)

plt.show()

# %%
#add red color for frequent classes
counter_classes_gt_1 = {}

for i in counter_classes.items():
    if i[1] > 1:
        counter_classes_gt_1[i[0]] = i[1]
    
max_val = max(counter_classes_gt_1.values())

# %%
for i in range(len(list_classes_for_html)):
    c = re.findall('<div>\w+', list_classes_for_html[i])
    if len(c) != 0:
        for j in counter_classes_gt_1:
            if j == c[0][5:]:
                list_classes_for_html[i] = '<div style="color: rgb(' + \
                str(255 - (max_val/counter_classes_gt_1[j])*(max_val/2)) + \
                ', 0, 0)">' + list_classes_for_html[i][5:]

# %%
html_file = open('classes.html', 'w')
html_file.write(''.join(map(str, list_classes_for_html)))
html_file.close()

# %%
print(counter_classes_gt_1)
# Out:
# {'UserWarning': 4, '_ndptr': 2, 'DiagonalArray': 2, 'C': 12, 'D': 2, 'ABCPolyBase': 6, 'RankWarning': 2, 'PolyError': 2, 'Exception': 12, 'TestConstants': 7, 'TestArithmetic': 6, 'TestEvaluation': 6, 'TestIntegral': 6, 'TestDerivative': 6, 'TestVander': 7, 'TestFitting': 5, 'TestCompanion': 6, 'TestGauss': 5, 'TestMisc': 7, 'TestRepr': 4, 'TestInterpolate': 2, 'TestInt': 2, '_GenericTest': 4, 'TestArrayEqual': 2, 'mod': 2, 'TestReturnReal': 3, 'TestReturnCharacter': 2, 'TestReturnLogical': 2, 'TestReturnComplex': 2, 'A': 24, 'TestReturnInteger': 2, 'CPUInfoBase': 6, 'MSVCCompiler': 3, '_MSVCCompiler': 2, 'UnixCCompiler': 3, 'IntelCCompiler': 2, 'IntelCCompilerW': 2, 'NotFoundError': 13, 'DistutilsError': 2, 'LapackNotFoundError': 2, 'BlasNotFoundError': 2, 'system_info': 25, 'fftw_info': 8, 'mkl_info': 3, 'atlas_info': 5, 'atlas_blas_info': 2, 'atlas_threads_info': 2, 'atlas_3_10_info': 4, 'atlas_3_10_blas_info': 2, 'atlas_3_10_threads_info': 2, 'lapack_ilp64_opt_info': 2, 'blas_ilp64_opt_info': 2, 'blas_info': 3, 'openblas_info': 3, 'openblas_lapack_info': 2, 'openblas_ilp64_info': 3, '_numpy_info': 4, '_pkg_config_info': 11, 'IOError': 2, 'Log': 2, '_system_info': 4, 'GnuFCompiler': 3, 'FCompiler': 18, 'BaseIntelFCompiler': 3, 'IntelFCompiler': 3, 'IntelVisualFCompiler': 3, 'BaseNAGFCompiler': 3, 'Command': 3, 'LinalgTestCase': 8, '_TestNormBase': 6, '_TestNorm2D': 2, 'TestRegression': 8, 'TestDot': 2, 'TestIndexing': 2, 'TestPower': 3, 'TestView': 3, 'TestSubclassing': 2, 'TestConcatenator': 3, 'TestFFTShift': 2, 'ConverterError': 2, 'nd_grid': 3, 'AxisConcatenator': 4, 'DummyArray': 2, 'BytesIO': 2, 'RoundtripTest': 3, 'list': 2, 'LoadTxtBase': 3, 'TestPathUsage': 2, 'OptOut': 2, 'ArrayLike': 5, 'TestAverage': 2, 'Foo': 3, 'TestUnique': 2, 'TestCov': 2, 'TestBincount': 2, 'TestMedian': 2, 'TestCommonType': 2, 'TestIsscalar': 2, 'MyArray': 5, 'TestApplyAlongAxis': 2, 'TestApplyOverAxes': 2, 'TestPolynomial': 2, 'SharedNanFunctionsTestsMixin': 4, 'dict': 2, 'ndarray': 5, 'UFuncTypeError': 4, '_UFuncCastingError': 3, '_TimelikeFormat': 3, 'memmap': 2, 'Other': 4, 'B': 6, 'TestTypes': 2, 'TestConversion': 2, 'TestSizeOf': 2, '_DeprecationTestCase': 27, '_VisibleDeprecationTestCase': 2, 'TestAlen': 2, '_FilterInvalids': 7, 'TestComparisons': 4, 'FunkyType': 2, 'TestBool': 2, 'TestMinMax': 2, 'with_wrap': 3, 'object': 7, 'TestChoose': 2, 'TestAttributes': 2, 'CreateZeros': 7, 'CreateValues': 12, 'ReadValuesPlain': 3, 'ReadValuesNested': 3, 'TestHalf': 2, 'Dummy': 2, 'AssignValues': 7, 'ByteorderValues': 7, 'StringConverterTestCase': 8, 'TestRecord': 3, 'TestPickling': 2, 'dt': 2, 'TestResize': 2, 'TestClip': 2, 'TestBroadcast': 4, 'TestCommaDecimalPointLocale': 2, 'CommaDecimalPointLocale': 3, 'TestTake': 2, 'Wrapper': 2, 'TestMethods': 2, 'SomeClass': 2, 'MatmulCommon': 3, 'NotConvertible': 2, 'MyAlwaysEqual': 3, 'T': 2, 'AbstractTest': 4, 'Base': 5, 'TestPhilox': 2, 'TestPCG64': 2, 'TestMT19937': 2, 'TestSFC64': 2, 'TestDefaultRNG': 2, 'RNG': 6, 'M': 5, 'TestSeed': 3, 'TestBinomial': 3, 'TestMultinomial': 3, 'TestSetState': 3, 'TestRandomDist': 3, 'TestThread': 3, 'TestSingleEltArrayInput': 3, 'TestRandint': 2, '_fromnxfunction': 5, 'MAxisConcatenator': 2, 'MAError': 2, '_MaskedUFunc': 5, 'MaskedArray': 7, 'TestUfuncs': 2}
